# %% [markdown]
# # NAME: PRINCESS OSEI BONSU
# # ID : 10979224
# # DEPARTMENT : BIOMEDICAL ENGINEERING
# # PROJECT 1

# %%
import pandas as pd

# %%
dataset = pd.read_csv('data.csv')

# %%
dataset
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS AND DATA CLEANING

# %%
dataset.shape
# Out:
# (1601, 13)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %%
dataset.rename(columns={'fixed acidity':'fixed_acidity'}, inplace = True)
dataset.rename(columns={'volatile acidity':'volatile_acidity'}, inplace = True)

# %%
dataset.rename(columns={'citric acid':'citric_acid'}, inplace = True)
dataset.rename(columns={'free sulfur dioxide':'free_sulfur_dioxide'}, inplace = True)
dataset.rename(columns={'total sulfur dioxide':'total_sulfur_dioxide'}, inplace = True)
dataset.rename(columns={'residual sugar':'residual_sugar'}, inplace = True)

# %%
dataset
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
df= dataset.dropna()

# %%
df
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %% [markdown]
# ##### The null values can be droped, imputed or filled with a default value. But in this case it can only be droped since they represent a small percentge of the dataset.

# %% [markdown]
# ### DATA

# %%
df.drop_duplicates()
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
df.head()
# Out:
#    ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0   1            7.4              0.70         0.00             1.9
# 1   2            7.8              0.88         0.00             2.6
# 3   4           11.2              0.28         0.56             1.9
# 4   5            7.4              0.70         0.00             1.9
# 5   6            7.4              0.66         0.00             1.8
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
# 5      0.075                 13.0                  40.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4      5.0
# 1       0.68      9.8      5.0
# 3       0.58      9.8      6.0
# ...

# %%
df.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %%
df['sulphates'].describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
df['density'].describe()
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %%
df['alcohol'].describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
df['pH'].describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
df['quality'].describe()
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
df['total_sulfur_dioxide'].describe()
# Out:
# count    1591.000000
# mean       46.498429
# std        32.998659
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total_sulfur_dioxide, dtype: float64

# %%
df['free_sulfur_dioxide'].describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free_sulfur_dioxide, dtype: float64

# %%
df['chlorides'].describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
df['residual_sugar'].describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual_sugar, dtype: float64

# %%
df['citric_acid'].describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric_acid, dtype: float64

# %%
df['volatile_acidity'].describe()
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile_acidity, dtype: float64

# %%
df['fixed_acidity'].describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed_acidity, dtype: float64

# %%
# The statistical measures or inferences gives a general idea of the properties of the data

# %% [markdown]
# ## DATA ANLYSIS AND VISUALIZATIONS

# %% [markdown]
# ### STATISTICAL INFERENCES

# %% [markdown]
# ### AVERAGE VALUES (MEAN)

# %%
mean_fixed_acidity = df.fixed_acidity.mean()
mean_volatile_acidity = df.volatile_acidity.mean()
mean_citric_acid = df.citric_acid.mean()
mean_residual_sugar = df.residual_sugar.mean()
mean_chlorides= df.chlorides.mean()
mean_free_sulfur_dioxide= df.free_sulfur_dioxide.mean()
mean_total_sulfur_dioxide = df.total_sulfur_dioxide.mean()
mean_density = df.density.mean()
mean_pH = df.pH.mean()
mean_sulphates = df.sulphates.mean()
mean_alcohol = df.alcohol.mean()
mean_quality= df.quality.mean()

# %%
print(f'\nfixed_acidity: {mean_fixed_acidity}')
print(f'\nvolatile_acidity: {mean_volatile_acidity}')
print(f'\ncitric_acid: {mean_citric_acid}')
print(f'\nresidual_sugar: {mean_residual_sugar}')
print(f'\nchlorides: {mean_chlorides}')
print(f'\nfree_sulfur_dioxide: {mean_free_sulfur_dioxide}')
print(f'\ntotal_sulfur_dioxide: {mean_total_sulfur_dioxide}')
print(f'\ndensity: {mean_density}')
print(f'\npH: {mean_pH}')
print(f'\nsulphates: {mean_sulphates}')
print(f'\nalcohol: {mean_alcohol}')
print(f'\nquality: {mean_quality}')
# Out:
# fixed_acidity: 8.32061596480201
#
# volatile_acidity: 0.5276807039597737
#
# citric_acid: 0.27147705845380266
#
# residual_sugar: 2.5407605279698307
#
# chlorides: 0.08749968573224387
#
# free_sulfur_dioxide: 15.861722187303583
#
# total_sulfur_dioxide: 46.49842866121936
#
# density: 0.9967465304839724
#
# pH: 3.3113576367064743
#
# sulphates: 0.6586109365179132
#
# alcohol: 10.42605279698303
#
# quality: 5.637963544940289

# %% [markdown]
# ### MEDIAN VALUES

# %%
median_fixed_acidity = df.fixed_acidity.median()
median_volatile_acidity = df.volatile_acidity.median()
median_citric_acid = df.citric_acid.median()
median_residual_sugar = df.residual_sugar.median()
median_chlorides= df.chlorides.median()
median_free_sulfur_dioxide= df.free_sulfur_dioxide.median()
median_total_sulfur_dioxide = df.total_sulfur_dioxide.median()
median_density = df.density.median()
median_pH = df.pH.median()
median_sulphates = df.sulphates.median()
median_alcohol = df.alcohol.median()
median_quality= df.quality.median()

# %%
print(f'\nfixed_acidity: {median_fixed_acidity}')
print(f'\nvolatile_acidity: {median_volatile_acidity}')
print(f'\ncitric_acid: {median_citric_acid}')
print(f'\nresidual_sugar: {median_residual_sugar}')
print(f'\nchlorides: {median_chlorides}')
print(f'\nfree_sulfur_dioxide: {median_free_sulfur_dioxide}')
print(f'\ntotal_sulfur_dioxide: {median_total_sulfur_dioxide}')
print(f'\ndensity: {median_density}')
print(f'\npH: {median_pH}')
print(f'\nsulphates: {median_sulphates}')
print(f'\nalcohol: {median_alcohol}')
print(f'\nquality: {median_quality}')
# Out:
# fixed_acidity: 7.9
#
# volatile_acidity: 0.52
#
# citric_acid: 0.26
#
# residual_sugar: 2.2
#
# chlorides: 0.079
#
# free_sulfur_dioxide: 14.0
#
# total_sulfur_dioxide: 38.0
#
# density: 0.99675
#
# pH: 3.31
#
# sulphates: 0.62
#
# alcohol: 10.2
#
# quality: 6.0

# %% [markdown]
# ### MODE VALUES

# %%
mode_fixed_acidity = df.fixed_acidity.mode().iloc[0]
mode_volatile_acidity = df.volatile_acidity.mode().iloc[0]
mode_citric_acid = df.citric_acid.mode().iloc[0]
mode_residual_sugar = df.residual_sugar.mode().iloc[0]
mode_chlorides= df.chlorides.mode().iloc[0]
mode_free_sulfur_dioxide= df.free_sulfur_dioxide.mode().iloc[0]
mode_total_sulfur_dioxide = df.total_sulfur_dioxide.mode().iloc[0]
mode_density = df.density.mode().iloc[0]
mode_pH = df.pH.mode().iloc[0]
mode_sulphates = df.sulphates.mode().iloc[0]
mode_alcohol = df.alcohol.mode().iloc[0]
mode_quality= df.quality.mode().iloc[0]

# %%
print(f'\nfixed_acidity: {mode_fixed_acidity}')
print(f'\nvolatile_acidity: {mode_volatile_acidity}')
print(f'\ncitric_acid: {mode_citric_acid}')
print(f'\nresidual_sugar: {mode_residual_sugar}')
print(f'\nchlorides: {mode_chlorides}')
print(f'\nfree_sulfur_dioxide: {mode_free_sulfur_dioxide}')
print(f'\ntotal_sulfur_dioxide: {mode_total_sulfur_dioxide}')
print(f'\ndensity: {mode_density}')
print(f'\npH: {mode_pH}')
print(f'\nsulphates: {mode_sulphates}')
print(f'\nalcohol: {mode_alcohol}')
print(f'\nquality: {mode_quality}')
# Out:
# fixed_acidity: 7.2
#
# volatile_acidity: 0.6
#
# citric_acid: 0.0
#
# residual_sugar: 2.0
#
# chlorides: 0.08
#
# free_sulfur_dioxide: 6.0
#
# total_sulfur_dioxide: 28.0
#
# density: 0.9972
#
# pH: 3.3
#
# sulphates: 0.6
#
# alcohol: 9.5
#
# quality: 5.0

# %% [markdown]
# ### STANDARD DEVIATION

# %%
std_dev_fixed_acidity = df.fixed_acidity.std()
std_dev_volatile_acidity = df.volatile_acidity.mode().std()
std_dev_citric_acid = df.citric_acid.mode().std()
std_dev_residual_sugar = df.residual_sugar.mode().std()
std_dev_chlorides= df.chlorides.mode().std()
std_dev_free_sulfur_dioxide= df.free_sulfur_dioxide.mode().std()
std_dev_total_sulfur_dioxide = df.total_sulfur_dioxide.mode().std()
std_dev_density = df.density.mode().std()
std_dev_pH = df.pH.mode().std()
std_dev_sulphates = df.sulphates.std()
std_dev_alcohol = df.alcohol.mode().std()
std_dev_quality= df.quality.mode().std()

# %%
print(f'\nfixed_acidity: {std_dev_fixed_acidity}')
print(f'\nvolatile_acidity: {std_dev_volatile_acidity}')
print(f'\ncitric_acid: {std_dev_citric_acid}')
print(f'\nresidual_sugar: {std_dev_residual_sugar}')
print(f'\nchlorides: {std_dev_chlorides}')
print(f'\nfree_sulfur_dioxide: {std_dev_free_sulfur_dioxide}')
print(f'\ntotal_sulfur_dioxide: {std_dev_total_sulfur_dioxide}')
print(f'\ndensity: {std_dev_density}')
print(f'\npH: {std_dev_pH}')
print(f'\nsulphates: {std_dev_sulphates}')
print(f'\nalcohol: {std_dev_alcohol}')
print(f'\nquality: {std_dev_quality}')
# Out:
# fixed_acidity: 1.7401336962216718
#
# volatile_acidity: nan
#
# citric_acid: nan
#
# residual_sugar: nan
#
# chlorides: nan
#
# free_sulfur_dioxide: nan
#
# total_sulfur_dioxide: nan
#
# density: nan
#
# pH: nan
#
# sulphates: 0.16978645516738008
#
# alcohol: nan
#
# quality: nan

# %%
import seaborn as sns

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ### MINIMUM VALUES

# %%
 df.min()
# Out:
# ID                      1.00000
# fixed_acidity           4.60000
# volatile_acidity        0.12000
# citric_acid             0.00000
# residual_sugar          0.90000
# chlorides               0.01200
# free_sulfur_dioxide     1.00000
# total_sulfur_dioxide    6.00000
# density                 0.99007
# pH                      2.74000
# sulphates               0.33000
# alcohol                 8.40000
# quality                 3.00000
# dtype: float64

# %% [markdown]
# ### MAXIMUM VALUES

# %%
df.max()
# Out:
# ID                      1601.00000
# fixed_acidity             15.90000
# volatile_acidity           1.58000
# citric_acid                1.00000
# residual_sugar            15.50000
# chlorides                  0.61100
# free_sulfur_dioxide       72.00000
# total_sulfur_dioxide     289.00000
# density                    1.00369
# pH                         4.01000
# sulphates                  2.00000
# alcohol                   14.90000
# quality                    8.00000
# dtype: float64

# %%
range = df.max() - df.min()

# %%
range
# Out:
# ID                      1600.00000
# fixed_acidity             11.30000
# volatile_acidity           1.46000
# citric_acid                1.00000
# residual_sugar            14.60000
# chlorides                  0.59900
# free_sulfur_dioxide       71.00000
# total_sulfur_dioxide     283.00000
# density                    0.01362
# pH                         1.27000
# sulphates                  1.67000
# alcohol                    6.50000
# quality                    5.00000
# dtype: float64

# %%
df.corr()
# Out:
#                             ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                    1.000000      -0.268371         -0.006833    -0.156712
# fixed_acidity        -0.268371       1.000000         -0.256737     0.672306
# volatile_acidity     -0.006833      -0.256737          1.000000    -0.551511
# citric_acid          -0.156712       0.672306         -0.551511     1.000000
# residual_sugar       -0.031780       0.114839          0.001336     0.143731
# chlorides            -0.119930       0.093857          0.061202     0.204294
# free_sulfur_dioxide   0.085616      -0.150261         -0.014598    -0.057619
# total_sulfur_dioxide -0.115795      -0.110992          0.074132     0.038593
# density              -0.368878       0.666876          0.022504     0.364181
# pH                    0.133390      -0.683788          0.234251    -0.543230
# sulphates            -0.127397       0.184937         -0.261872     0.313530
# ...

# %% [markdown]
# ##### From the data above it can be seen that the quality of the wine produced in our company is good. The alcohol - quality corelation from the data is  0.475444  which is a good . From this data it could be seen that our company produce  good quality wine.
#
# #### We can also deduce that the pH of the wine is very low. The wine is therefore fairly neutral.

# %%
df.columns
# Out:
# Index(['ID', 'fixed_acidity', 'volatile_acidity', 'citric_acid',
#        'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
#        'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
feature = ['fixed_acidity', 'volatile_acidity', 'citric_acid',
       'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
       'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol']

# %%
list(enumerate(feature))
# Out:
# [(0, 'fixed_acidity'),
#  (1, 'volatile_acidity'),
#  (2, 'citric_acid'),
#  (3, 'residual_sugar'),
#  (4, 'chlorides'),
#  (5, 'free_sulfur_dioxide'),
#  (6, 'total_sulfur_dioxide'),
#  (7, 'density'),
#  (8, 'pH'),
#  (9, 'sulphates'),
#  (10, 'alcohol')]

# %% [markdown]
# ## VISUALIZATIONS

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# #### The the inventories have a very good correlation with themselves.

# %%
sns.histplot(df['alcohol'], kde=False)
plt.show()

# %%
plt.hist(df['alcohol'])
plt.show()

# %%
sns.histplot(df.quality)

plt.show()

# %%
sns.boxplot(df['density'])
# Out:
# <Axes: >

# %%
content = df.filter(items=['pH', 'alcohol', 'quality'])

# %%
content
# Out:
#         pH  alcohol  quality
# 0     3.51      9.4      5.0
# 1     3.20      9.8      5.0
# 3     3.16      9.8      6.0
# 4     3.51      9.4      5.0
# 5     3.51      9.4      5.0
# ...    ...      ...      ...
# 1596  3.52     11.2      6.0
# 1597  3.42     11.0      6.0
# 1598  3.57     10.2      5.0
# 1599  3.39     11.0      6.0
# 1600  3.30     11.5      6.0
#
# [1591 rows x 3 columns]

# %%
sns.histplot(content)
plt.show()

# %%
Alcohol_quality = df.filter(items=['alcohol', 'quality'])

# %%
Alcohol_quality
# Out:
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# 5         9.4      5.0
# ...       ...      ...
# 1596     11.2      6.0
# 1597     11.0      6.0
# 1598     10.2      5.0
# 1599     11.0      6.0
# 1600     11.5      6.0
#
# [1591 rows x 2 columns]

# %%
sns.histplot(Alcohol_quality )

plt.show()

# %%
corelation = Alcohol_quality.corr()

# %%
corelation
# Out:
#           alcohol   quality
# alcohol  1.000000  0.475444
# quality  0.475444  1.000000

# %%
df.filter(items=['density', 'alcohol', 'quality'])
# Out:
#       density  alcohol  quality
# 0     0.99780      9.4      5.0
# 1     0.99680      9.8      5.0
# 3     0.99800      9.8      6.0
# 4     0.99780      9.4      5.0
# 5     0.99780      9.4      5.0
# ...       ...      ...      ...
# 1596  0.99512     11.2      6.0
# 1597  0.99574     11.0      6.0
# 1598  0.99547     10.2      5.0
# 1599  0.99549     11.0      6.0
# 1600  0.99494     11.5      6.0
#
# [1591 rows x 3 columns]

# %%
df.filter(items=['pH', 'chlorides', 'sulphates'])
# Out:
#         pH  chlorides  sulphates
# 0     3.51      0.076       0.56
# 1     3.20      0.098       0.68
# 3     3.16      0.075       0.58
# 4     3.51      0.076       0.56
# 5     3.51      0.075       0.56
# ...    ...        ...        ...
# 1596  3.52      0.062       0.76
# 1597  3.42      0.076       0.75
# 1598  3.57      0.075       0.71
# 1599  3.39      0.067       0.66
# 1600  3.30      0.066       0.84
#
# [1591 rows x 3 columns]

# %%
df.filter(items=['residual_sugar', 'alcohol', 'quality'])
# Out:
#       residual_sugar  alcohol  quality
# 0                1.9      9.4      5.0
# 1                2.6      9.8      5.0
# 3                1.9      9.8      6.0
# 4                1.9      9.4      5.0
# 5                1.8      9.4      5.0
# ...              ...      ...      ...
# 1596             2.2     11.2      6.0
# 1597             2.3     11.0      6.0
# 1598             2.0     10.2      5.0
# 1599             3.6     11.0      6.0
# 1600             2.6     11.5      6.0
#
# [1591 rows x 3 columns]

# %%
Acidity = df.filter(like='acid')

# %%
Acidity
# Out:
#       fixed_acidity  volatile_acidity  citric_acid
# 0               7.4             0.700         0.00
# 1               7.8             0.880         0.00
# 3              11.2             0.280         0.56
# 4               7.4             0.700         0.00
# 5               7.4             0.660         0.00
# ...             ...               ...          ...
# 1596            5.9             0.550         0.10
# 1597            6.3             0.510         0.13
# 1598            5.9             0.645         0.12
# 1599            6.0             0.310         0.47
# 1600            7.2             0.390         0.44
#
# [1591 rows x 3 columns]

# %%
Acidity.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid
# 0            7.4              0.70         0.00
# 1            7.8              0.88         0.00
# 3           11.2              0.28         0.56
# 4            7.4              0.70         0.00
# 5            7.4              0.66         0.00

# %%
Acidity.corr()
# Out:
#                   fixed_acidity  volatile_acidity  citric_acid
# fixed_acidity          1.000000         -0.256737     0.672306
# volatile_acidity      -0.256737          1.000000    -0.551511
# citric_acid            0.672306         -0.551511     1.000000

# %%
labels = ['Acidic', 'Neutral', 'Basic']
sizes = [sum(df['pH'] < 7), sum(df['pH'] == 7), sum(df['pH'] > 7)]
colors = ['#ff9999','#66b3ff','#99ff99']
plt.pie(sizes, colors=colors, labels=labels, autopct='%2.2f%%', startangle=90)
plt.axis('equal')

plt.show()

# %% [markdown]
# ##### pH is the measure of the acidity and basicity of a subtance. From the chart it can be observerd that the pH of the dataset is acidic.

# %%
# histogram plots of individual columns
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(10,10))
axes[0,0].hist(df['fixed_acidity'], bins=20, color='blue', alpha=1)
axes[0,0].set_xlabel('Fixed_Acidity')
axes[0,0].set_ylabel('Frequency')
axes[0,1].hist(df['volatile_acidity'], bins=20, color='green', alpha=1)
axes[0,1].set_xlabel('Volatile_Acidity')
axes[0,1].set_ylabel('Frequency')
axes[1,0].hist(df['citric_acid'], bins=20, color='red', alpha=1)
axes[1,0].set_xlabel('Citric_Acid')
axes[1,0].set_ylabel('Frequency')
axes[2,0].hist(df['residual_sugar'], bins=20, color='purple', alpha=1)
axes[2,0].set_xlabel('residual_sugar')
axes[2,0].set_ylabel('Frequency')
axes[2,1].hist(df['chlorides'], bins=20, color='purple', alpha=1)
axes[2,1].set_xlabel('chlorides')
axes[2,1].set_ylabel('Frequency')

plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(10,10))
axes[0,0].hist(df['free_sulfur_dioxide'], bins=20, color='blue', alpha=1)
axes[0,0].set_xlabel('free_sulfur_dioxide')
axes[0,0].set_ylabel('Frequency')
axes[0,1].hist(df['total_sulfur_dioxide'], bins=20, color='green', alpha=1)
axes[0,1].set_xlabel('total_sulfur_dioxide')
axes[0,1].set_ylabel('Frequency')
axes[1,0].hist(df['pH'], bins=20, color='red', alpha=1)
axes[1,0].set_xlabel('pH')
axes[1,0].set_ylabel('Frequency')
axes[1,1].hist(df['sulphates'], bins=20, color='purple', alpha=1)
axes[1,1].set_xlabel('sulphates')
axes[1,1].set_ylabel('Frequency')
axes[2,0].hist(df['density'], bins=20, color='green', alpha=1)
axes[2,0].set_xlabel('density')
axes[2,0].set_ylabel('Frequency')
axes[2,1].hist(df['quality'], bins=20, color='purple', alpha=1)
axes[2,1].set_xlabel('quality')
axes[2,1].set_ylabel('Frequency')
axes[2,1].hist(df['alcohol'], bins=20, color='purple', alpha=1)
axes[2,1].set_xlabel('alcohol')
axes[2,1].set_ylabel('Frequency')

plt.show()

# %%
sns.pairplot(df, vars =['density','alcohol','quality','pH','chlorides','sulphates'],hue = 'fixed_acidity')

plt.show()

# %% [markdown]
# #####  The legend of the fixed_acidity shows the  concentrations of the various inventories.  The area with the deepest  colouration represent the area with high concentration of  of fixed_acidity.
